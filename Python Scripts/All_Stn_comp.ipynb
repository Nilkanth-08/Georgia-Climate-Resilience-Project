# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# Load your data
weather_D = pd.read_csv("Daniel field data.csv", parse_dates=['DATE'], index_col='DATE')
weather_B = pd.read_csv("Bush field data.csv", parse_dates=['DATE'], index_col='DATE')
weather_A = pd.read_csv("Appling data.csv", parse_dates=['DATE'], index_col='DATE')
weather_J = pd.read_csv("Johnston data.csv", parse_dates=['DATE'], index_col='DATE')
weather_L = pd.read_csv("Louisville data.csv", parse_dates=['DATE'], index_col='DATE')
weather_W = pd.read_csv("Waynesboro data.csv", parse_dates=['DATE'], index_col='DATE')

# %%
weather_B.index = pd.to_datetime(weather_B.index, format='%d-%m-%Y')
weather_D.index = pd.to_datetime(weather_D.index, format='%d-%m-%Y')
weather_A.index = pd.to_datetime(weather_A.index, format='%d-%m-%Y')
weather_J.index = pd.to_datetime(weather_J.index, format='%d-%m-%Y')
weather_L.index = pd.to_datetime(weather_L.index, format='%d-%m-%Y')
weather_W.index = pd.to_datetime(weather_W.index, format='%d-%m-%Y')

# %%
weather_B
# Out:
#                 STATION                               NAME  LATITUDE  \
# DATE
# 1945-01-01  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-01-02  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-01-03  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-01-04  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-01-05  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 2024-06-14  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-06-15  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-06-16  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-06-17  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-06-18  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             LONGITUDE  ELEVATION  PRCP  TAVG  TMAX  TMIN
# DATE
# 1945-01-01  -81.96353       40.9  0.31   NaN  63.0  30.0
# 1945-01-02  -81.96353       40.9  0.00   NaN  46.0  24.0
# 1945-01-03  -81.96353       40.9  0.00   NaN  52.0  31.0
# 1945-01-04  -81.96353       40.9  0.00   NaN  58.0  37.0
# 1945-01-05  -81.96353       40.9  0.00   NaN  58.0  33.0
# ...               ...        ...   ...   ...   ...   ...
# 2024-06-14  -81.96353       40.9  0.00  78.0  94.0  61.0
# 2024-06-15  -81.96353       40.9  0.30  81.0  97.0  67.0
# 2024-06-16  -81.96353       40.9  0.55  79.0  93.0  69.0
# 2024-06-17  -81.96353       40.9  0.46  78.0  89.0  70.0
# 2024-06-18  -81.96353       40.9   NaN  75.0   NaN   NaN
#
# [29024 rows x 9 columns]

# %%
weather_A.apply(pd.isnull).sum()
# Out:
# STATION          0
# NAME             0
# LATITUDE         0
# LONGITUDE        0
# ELEVATION        0
# DAPR         22546
# DASF         22557
# MDPR         22544
# MDSF         22557
# PRCP            87
# SNOW          1295
# SNWD          1470
# TMAX            96
# TMIN            90
# dtype: int64

# %%
weather_D=weather_D.dropna(subset=['PRCP', 'TMAX', 'TMIN'])
weather_B=weather_B.dropna(subset=['PRCP', 'TMAX', 'TMIN'])
weather_A=weather_A.dropna(subset=['PRCP', 'TMAX', 'TMIN'])
weather_J=weather_J.dropna(subset=['PRCP', 'TMAX', 'TMIN'])
weather_L=weather_L.dropna(subset=['PRCP', 'TMAX', 'TMIN'])
weather_W=weather_W.dropna(subset=['PRCP', 'TMAX', 'TMIN'])

# %%
weather_A.apply(pd.isnull).sum()
# Out:
# STATION          0
# NAME             0
# LATITUDE         0
# LONGITUDE        0
# ELEVATION        0
# DAPR         22377
# DASF         22377
# MDPR         22377
# MDSF         22377
# PRCP             0
# SNOW          1278
# SNWD          1453
# TMAX             0
# TMIN             0
# dtype: int64

# %%
weather_B = weather_B.copy()
weather_B['seasonal_year'] = weather_B.index.year 
weather_D = weather_D.copy()
weather_D['seasonal_year'] = weather_D.index.year 
weather_A = weather_A.copy()
weather_A['seasonal_year'] = weather_A.index.year 
weather_J = weather_J.copy()
weather_J['seasonal_year'] = weather_J.index.year 
weather_L = weather_L.copy()
weather_L['seasonal_year'] = weather_L.index.year 
weather_W = weather_W.copy()
weather_W['seasonal_year'] = weather_W.index.year

# %%
weather_D
# Out:
#                 STATION                                 NAME  LATITUDE  \
# DATE
# 1998-04-01  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-02  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-03  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-04  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-05  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# ...                 ...                                  ...       ...
# 2024-06-19  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2024-06-20  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2024-06-21  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2024-06-22  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2024-06-23  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
#
#             LONGITUDE  ELEVATION  PRCP  SNOW  TAVG  TMAX  TMIN  seasonal_year
# DATE
# 1998-04-01  -82.03847      125.1  0.43   NaN  69.0  76.0  61.0           1998
# 1998-04-02  -82.03847      125.1  0.00   NaN  70.0  83.0  57.0           1998
# 1998-04-03  -82.03847      125.1  2.44   NaN  63.0  67.0  58.0           1998
# 1998-04-04  -82.03847      125.1  0.00   NaN  60.0  66.0  53.0           1998
# 1998-04-05  -82.03847      125.1  0.00   NaN  55.0  66.0  44.0           1998
# ...               ...        ...   ...   ...   ...   ...   ...            ...
# 2024-06-19  -82.03847      125.1  0.00   NaN   NaN  91.0  71.0           2024
# 2024-06-20  -82.03847      125.1  0.00   NaN   NaN  92.0  71.0           2024
# 2024-06-21  -82.03847      125.1  0.00   NaN   NaN  95.0  69.0           2024
# 2024-06-22  -82.03847      125.1  0.00   NaN   NaN  93.0  77.0           2024
# 2024-06-23  -82.03847      125.1  0.00   NaN   NaN  98.0  76.0           2024
#
# [9490 rows x 11 columns]

# %%
Winter_Bdata = weather_B[(weather_B.index.month == 12) &(weather_B.index.year>=1990) | (weather_B.index.month <= 2) & (weather_B.index.year>1990) & (weather_B.index.year<=2023)]
Winter_Ddata = weather_D[(weather_D.index.month == 12) &(weather_D.index.year>=1998) | (weather_D.index.month <= 2) & (weather_D.index.year>1998) & (weather_D.index.year<=2023)]
Winter_Adata = weather_A[(weather_A.index.month == 12) &(weather_A.index.year>=1990) | (weather_A.index.month <= 2) & (weather_A.index.year>1990) & (weather_A.index.year<=2023)]
Winter_Jdata = weather_J[(weather_J.index.month == 12) &(weather_J.index.year>=1990) | (weather_J.index.month <= 2) & (weather_J.index.year>1990) & (weather_J.index.year<=2023)]
Winter_Ldata = weather_L[(weather_L.index.month == 12) &(weather_L.index.year>=1990) | (weather_L.index.month <= 2) & (weather_L.index.year>1990) & (weather_L.index.year<=2023)]
Winter_Wdata = weather_W[(weather_W.index.month == 12) &(weather_W.index.year>=1990) | (weather_W.index.month <= 2) & (weather_W.index.year>1990) & (weather_W.index.year<=2023)]

# %%
Winter_Wdata
# Out:
#                 STATION                   NAME  LATITUDE  LONGITUDE  \
# DATE
# 1991-12-02  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 1991-12-03  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 1991-12-04  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 1991-12-05  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 1991-12-06  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# ...                 ...                    ...       ...        ...
# 2023-12-27  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 2023-12-28  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 2023-12-29  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 2023-12-30  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
# 2023-12-31  USC00099194  WAYNESBORO 2 S, GA US  33.07129  -82.00728
#
#             ELEVATION  DAPR  MDPR  PRCP  SNOW  SNWD  TMAX  TMIN  seasonal_year
# DATE
# 1991-12-02       84.4   NaN   NaN  0.00   0.0   0.0  77.0  36.0           1991
# 1991-12-03       84.4   NaN   NaN  0.00   0.0   0.0  78.0  36.0           1991
# 1991-12-04       84.4   NaN   NaN  1.60   0.0   0.0  79.0  36.0           1991
# 1991-12-05       84.4   NaN   NaN  0.00   0.0   0.0  51.0  24.0           1991
# 1991-12-06       84.4   NaN   NaN  0.00   0.0   0.0  51.0  24.0           1991
# ...               ...   ...   ...   ...   ...   ...   ...   ...            ...
# 2023-12-27       84.4   NaN   NaN  0.26   0.0   0.0  66.0  57.0           2023
# 2023-12-28       84.4   NaN   NaN  0.00   0.0   0.0  65.0  45.0           2023
# 2023-12-29       84.4   NaN   NaN  0.00   0.0   0.0  62.0  37.0           2023
# 2023-12-30       84.4   NaN   NaN  0.00   0.0   0.0  51.0  33.0           2023
# 2023-12-31       84.4   NaN   NaN  0.00   0.0   0.0  54.0  28.0           2023
#
# [2770 rows x 13 columns]

# %%
seasonal_avg_tempB = Winter_Bdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempD = Winter_Ddata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempA = Winter_Adata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempJ = Winter_Jdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempL = Winter_Ldata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempW = Winter_Wdata.groupby('seasonal_year')['TMAX'].mean()

# %%
seasonal_avg_tempB = Winter_Bdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempD = Winter_Ddata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempA = Winter_Adata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempJ = Winter_Jdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempL = Winter_Ldata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempW = Winter_Wdata.groupby('seasonal_year')['TMAX'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
plt.plot(yearsW, temp_valuesW, 'o', color='purple', label='Waynesboro Station tmax')
# Plotting trend line
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b-',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = (1 - t.cdf(abs(t_statistic), df)) * 2
    return slope, SE, t_statistic, p_value

# slope and standard error calculation for each dataset
# Call the function and unpack all returned values
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(48, 68))

plt.title('All Stations Daily Average Maximum Temperature Comparison for Each Winter Season')
plt.xlabel('Winter Season (Year Ending)')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.11, Standard Error = 0.04, T-Stat = 2.38, p-value = 0.0234
# Daniel Field: Slope = 0.16, Standard Error = 0.07, T-Stat = 2.20, p-value = 0.0380
# Appling Station: Slope = 0.09, Standard Error = 0.05, T-Stat = 2.03, p-val = 0.0503
# Johnston Station: Slope = 0.04, Standard Error = 0.05, T-Stat = 0.87, p-val = 0.3881
# Louisville Station: Slope = 0.04, Standard Error = 0.05, T-Stat = 0.72, p-val = 0.4782
# Waynesboro Station: Slope = 0.13, Standard Error = 0.05, T-Stat = 2.51, p-val = 0.0174

# %%
spring_Bdata = weather_B[(weather_B.index.month >= 3) &(weather_B.index.month <= 5)& (weather_B.index.year>=1991) & (weather_B.index.year<=2023)]
spring_Ddata = weather_D[(weather_D.index.month >= 3) &(weather_D.index.month <= 5)& (weather_D.index.year>=1998) & (weather_D.index.year<=2023)]
spring_Adata = weather_A[(weather_A.index.month >= 3) &(weather_A.index.month <= 5)& (weather_A.index.year>=1991) & (weather_A.index.year<=2023)]
spring_Jdata = weather_J[(weather_J.index.month >= 3) &(weather_J.index.month <= 5)& (weather_J.index.year>=1991) & (weather_J.index.year<=2023)]
spring_Ldata = weather_L[(weather_L.index.month >= 3) &(weather_L.index.month <= 5)& (weather_L.index.year>=1991) & (weather_L.index.year<=2023)]
spring_Wdata = weather_W[(weather_W.index.month >= 3) &(weather_W.index.month <= 5)& (weather_W.index.year>=1991) & (weather_W.index.year<=2023)]

# %%
spring_Ddata
# Out:
#                 STATION                                 NAME  LATITUDE  \
# DATE
# 1998-04-01  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-02  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-03  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-04  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 1998-04-05  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# ...                 ...                                  ...       ...
# 2023-05-27  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2023-05-28  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2023-05-29  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2023-05-30  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
# 2023-05-31  USW00013837  AUGUSTA DANIEL FIELD AIRPORT, GA US   33.4668
#
#             LONGITUDE  ELEVATION  PRCP  SNOW  TAVG  TMAX  TMIN  seasonal_year
# DATE
# 1998-04-01  -82.03847      125.1  0.43   NaN  69.0  76.0  61.0           1998
# 1998-04-02  -82.03847      125.1  0.00   NaN  70.0  83.0  57.0           1998
# 1998-04-03  -82.03847      125.1  2.44   NaN  63.0  67.0  58.0           1998
# 1998-04-04  -82.03847      125.1  0.00   NaN  60.0  66.0  53.0           1998
# 1998-04-05  -82.03847      125.1  0.00   NaN  55.0  66.0  44.0           1998
# ...               ...        ...   ...   ...   ...   ...   ...            ...
# 2023-05-27  -82.03847      125.1  1.17   NaN   NaN  64.0  54.0           2023
# 2023-05-28  -82.03847      125.1  0.00   NaN   NaN  66.0  56.0           2023
# 2023-05-29  -82.03847      125.1  0.00   NaN   NaN  81.0  57.0           2023
# 2023-05-30  -82.03847      125.1  0.00   NaN   NaN  83.0  62.0           2023
# 2023-05-31  -82.03847      125.1  0.00   NaN   NaN  77.0  68.0           2023
#
# [2351 rows x 11 columns]

# %%
seasonal_avg_tempB = spring_Bdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempD = spring_Ddata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempA = spring_Adata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempJ = spring_Jdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempL = spring_Ldata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempW = spring_Wdata.groupby('seasonal_year')['TMAX'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Calculate overall mean
#overall_meanB = seasonal_avg_tempB.mean()
#overall_meanD = seasonal_avg_tempD.mean()

# Plotting
plt.figure(figsize=(16, 7))
#plt.plot(yearsB, temp_valuesB,'o', color='orange', label='Bush Winter Tmax')
#plt.plot(yearsD, temp_valuesD,'o', color='red', label='Daniel Winter Tmax')

# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')
#plt.axhline(y=overall_meanB, color='blue', linestyle='--', linewidth=1.5, label='Overall Bush Field Mean')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')
#plt.axhline(y=overall_meanD, color='Green', linestyle='--', linewidth=1.5, label='Overall Daniel Field Mean')

plt.plot(yearsA, trend_lineA, 'b-',linewidth=2, label='Appling station Trend Line')

#plt.plot(yearsC, trend_lineC, 'g-',linewidth=2, label='Clarks hill station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g-',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y-',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = (1 - t.cdf(abs(t_statistic), df)) * 2
    return slope, SE, t_statistic, p_value

# slope and standard error calculation for each dataset
# Call the function and unpack all returned values
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(70, 82))

plt.title('All Stations Daily Average Maximum Temperature Comparison for Each Spring Season')
plt.xlabel('YEAR')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.06, Standard Error = 0.04, T-Stat = 1.63, p-value = 0.1124
# Daniel Field: Slope = 0.07, Standard Error = 0.05, T-Stat = 1.34, p-value = 0.1927
# Appling Station: Slope = 0.02, Standard Error = 0.04, T-Stat = 0.41, p-val = 0.68
# Johnston Station: Slope = 0.01, Standard Error = 0.05, T-Stat = 0.11, p-val = 0.91
# Louisville Station: Slope = -0.03, Standard Error = 0.04, T-Stat = -0.61, p-val = 0.55
# Waynesboro Station: Slope = 0.01, Standard Error = 0.04, T-Stat = 0.15, p-val = 0.88

# %%
summer_Bdata = weather_B[(weather_B.index.month >= 6) &(weather_B.index.month <= 8)& (weather_B.index.year>=1990)& (weather_B.index.year<=2023)]
summer_Ddata = weather_D[(weather_D.index.month >= 6) &(weather_D.index.month <= 8)& (weather_D.index.year>=1998)& (weather_D.index.year<=2023)]
summer_Adata = weather_A[(weather_A.index.month >= 6) &(weather_A.index.month <= 8)& (weather_A.index.year>=1990)& (weather_A.index.year<=2023)]
summer_Jdata = weather_J[(weather_J.index.month >= 6) &(weather_J.index.month <= 8)& (weather_J.index.year>=1990)& (weather_J.index.year<=2023)]
summer_Ldata = weather_L[(weather_L.index.month >= 6) &(weather_L.index.month <= 8)& (weather_L.index.year>=1990)& (weather_L.index.year<=2023)]
summer_Wdata = weather_W[(weather_W.index.month >= 6) &(weather_W.index.month <= 8)& (weather_W.index.year>=1990)& (weather_W.index.year<=2023)]

# %%
seasonal_avg_tempB = summer_Bdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempD = summer_Ddata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempA = summer_Adata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempJ = summer_Jdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempL = summer_Ldata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempW = summer_Wdata.groupby('seasonal_year')['TMAX'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Calculate overall mean
#overall_meanB = seasonal_avg_tempB.mean()
#overall_meanD = seasonal_avg_tempD.mean()

# Plotting
plt.figure(figsize=(16, 7))
#plt.plot(yearsB, temp_valuesB,'o', color='orange', label='Bush Winter Tmax')
#plt.plot(yearsD, temp_valuesD,'o', color='red', label='Daniel Winter Tmax')

# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')
#plt.axhline(y=overall_meanB, color='blue', linestyle='--', linewidth=1.5, label='Overall Bush Field Mean')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2.5, label='Daniel Field Trend Line')
#plt.axhline(y=overall_meanD, color='Green', linestyle='--', linewidth=1.5, label='Overall Daniel Field Mean')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=1, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=1.5, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=1.5, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--',linewidth=1, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = (1 - t.cdf(abs(t_statistic), df)) * 2
    return slope, SE, t_statistic, p_value

# slope and standard error calculation for each dataset
# Call the function and unpack all returned values
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(86,96))

plt.title('All Stations Daily Average Maximum Temperature Comparison for Each Summer Season')
plt.xlabel('YEAR')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.04, Standard Error = 0.04, T-Stat = 0.93, p-value = 0.3608
# Daniel Field: Slope = 0.07, Standard Error = 0.05, T-Stat = 1.34, p-value = 0.1924
# Appling Station: Slope = -0.00, Standard Error = 0.03, T-Stat = -0.02, p-val = 0.99
# Johnston Station: Slope = -0.04, Standard Error = 0.04, T-Stat = -1.08, p-val = 0.29
# Louisville Station: Slope = -0.04, Standard Error = 0.04, T-Stat = -1.05, p-val = 0.30
# Waynesboro Station: Slope = 0.01, Standard Error = 0.04, T-Stat = 0.13, p-val = 0.90

# %%
fall_Bdata = weather_B[(weather_B.index.month >= 9) &(weather_B.index.month <= 11)& (weather_B.index.year>=1991) & (weather_B.index.year<=2023)]
fall_Ddata = weather_D[(weather_D.index.month >= 9) &(weather_D.index.month <= 11)& (weather_D.index.year>=1991) & (weather_D.index.year<=2023)]
fall_Adata = weather_A[(weather_A.index.month >= 9) &(weather_A.index.month <= 11)& (weather_A.index.year>=1991) & (weather_A.index.year<=2023)]
fall_Jdata = weather_J[(weather_J.index.month >= 9) &(weather_J.index.month <= 11)& (weather_J.index.year>=1991) & (weather_J.index.year<=2023)]
fall_Ldata = weather_L[(weather_L.index.month >= 9) &(weather_L.index.month <= 11)& (weather_L.index.year>=1991) & (weather_L.index.year<=2023)]
fall_Wdata = weather_W[(weather_W.index.month >= 9) &(weather_W.index.month <= 11)& (weather_W.index.year>=1991) & (weather_W.index.year<=2023)]

# %%
seasonal_avg_tempB = fall_Bdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempD = fall_Ddata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempA = fall_Adata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempJ = fall_Jdata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempL = fall_Ldata.groupby('seasonal_year')['TMAX'].mean()
seasonal_avg_tempW = fall_Wdata.groupby('seasonal_year')['TMAX'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Calculate overall mean
#overall_meanB = seasonal_avg_tempB.mean()
#overall_meanD = seasonal_avg_tempD.mean()

# Plotting
plt.figure(figsize=(16, 7))
#plt.plot(yearsB, temp_valuesB,'o', color='orange', label='Bush Winter Tmax')
#plt.plot(yearsD, temp_valuesD,'o', color='red', label='Daniel Winter Tmax')

# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')
#plt.axhline(y=overall_meanB, color='blue', linestyle='--', linewidth=1.5, label='Overall Bush Field Mean')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')
#plt.axhline(y=overall_meanD, color='Green', linestyle='--', linewidth=1.5, label='Overall Daniel Field Mean')

plt.plot(yearsA, trend_lineA, 'b-',linewidth=2, label='Appling station Trend Line')

#plt.plot(yearsC, trend_lineC, 'g-',linewidth=2, label='Clarks hill station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g-',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y-',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')


def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    return slope, SE

# slope and standard error calculation for each dataset
slopeB, SEB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeB, SEB))

slopeD, SED = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeD, SED))

slopeA, SEA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeA, SEA))

slopeJ, SEJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeJ, SEJ))

slopeL, SEL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeL, SEL))

slopeW, SEW = calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeW, SEW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(72, 82))

plt.title('All Stations Daily Average Maximum Temperature Comparison for Each Fall Season')
plt.xlabel('YEAR')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.09, Standard Error = 0.03
# Daniel Field: Slope = 0.09, Standard Error = 0.05
# Appling Station: Slope = 0.05, Standard Error = 0.03
# Johnston Station: Slope = 0.01, Standard Error = 0.05
# Louisville Station: Slope = -0.01, Standard Error = 0.04
# Waynesboro Station: Slope = 0.11, Standard Error = 0.04

# %%
seasonal_avg_tempB = Winter_Bdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempD = Winter_Ddata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempA = Winter_Adata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempJ = Winter_Jdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempL = Winter_Ldata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempW = Winter_Wdata.groupby('seasonal_year')['TMIN'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
plt.plot(yearsW, temp_valuesW, 'o', color='purple', label='Waynesboro Station tmin')
# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g-',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = (1 - t.cdf(abs(t_statistic), df)) * 2
    return slope, SE, t_statistic, p_value

# slope and standard error calculation for each dataset
# Call the function and unpack all returned values
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Std Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Std Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Std Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Std Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Std Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Std Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(28, 47))

plt.title('All Stations Daily Average Minimum Temperature Comparison for Each Winter Season')
plt.xlabel('Winter Season (Year Ending)')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.09, Std Error = 0.05,T-Stat = 1.69, p-value = 0.1000
# Daniel Field: Slope = 0.20, Std Error = 0.08,T-Stat = 2.68, p-value = 0.0130
# Appling Station: Slope = 0.00, Std Error = 0.05,T-Stat = 0.11, p-value = 0.9162
# Johnston Station: Slope = 0.12, Std Error = 0.06,T-Stat = 2.05, p-value = 0.0487
# Louisville Station: Slope = -0.01, Std Error = 0.06,T-Stat = -0.18, p-value = 0.8620
# Waynesboro Station: Slope = 0.10, Std Error = 0.04,T-Stat = 2.27, p-value = 0.0304

# %%
seasonal_avg_tempB = spring_Bdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempD = spring_Ddata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempA = spring_Adata.groupby('seasonal_year')['TMIN'].mean()
#seasonal_avg_tempC = spring_Cdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempJ = spring_Jdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempL = spring_Ldata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempW = spring_Wdata.groupby('seasonal_year')['TMIN'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Calculate overall mean
#overall_meanB = seasonal_avg_tempB.mean()
#overall_meanD = seasonal_avg_tempD.mean()

# Plotting
plt.figure(figsize=(16, 7))
#plt.plot(yearsB, temp_valuesB,'o', color='orange', label='Bush Winter Tmax')
#plt.plot(yearsD, temp_valuesD,'o', color='red', label='Daniel Winter Tmax')

# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')
#plt.axhline(y=overall_meanB, color='blue', linestyle='--', linewidth=1.5, label='Overall Bush Field Mean')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')
#plt.axhline(y=overall_meanD, color='Green', linestyle='--', linewidth=1.5, label='Overall Daniel Field Mean')

plt.plot(yearsA, trend_lineA, 'b-',linewidth=2, label='Appling station Trend Line')

#plt.plot(yearsC, trend_lineC, 'g-',linewidth=2, label='Clarks hill station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g-',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y-',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    return slope, SE

# Example calculation for each dataset
slopeB, SEB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeB, SEB))

slopeD, SED = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeD, SED))

slopeA, SEA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeA, SEA))

slopeJ, SEJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeJ, SEJ))

slopeL, SEL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeL, SEL))

slopeW, SEW = calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeW, SEW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(43, 61))

plt.title('All Stations Daily Average Minimum Temperature Comparison for Each Spring Season')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.07, Standard Error = 0.04
# Daniel Field: Slope = 0.09, Standard Error = 0.05
# Appling Station: Slope = 0.01, Standard Error = 0.04
# Johnston Station: Slope = 0.16, Standard Error = 0.05
# Louisville Station: Slope = -0.02, Standard Error = 0.04
# Waynesboro Station: Slope = 0.03, Standard Error = 0.05

# %%
seasonal_avg_tempB = summer_Bdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempD = summer_Ddata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempA = summer_Adata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempJ = summer_Jdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempL = summer_Ldata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempW = summer_Wdata.groupby('seasonal_year')['TMIN'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
#plt.plot(yearsB, temp_valuesB,'o', color='orange', label='Bush Winter Tmax')
#plt.plot(yearsD, temp_valuesD,'o', color='red', label='Daniel Winter Tmax')

# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linestyle='--',linewidth=1.5, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=1.5, label='Appling station Trend Line')

#plt.plot(yearsC, trend_lineC, 'g-',linewidth=2, label='Clarks hill station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g-',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y-.',linewidth=1.5, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = (1 - t.cdf(abs(t_statistic), df)) * 2
    return slope, SE, t_statistic, p_value

# slope and standard error calculation for each dataset
# Call the function and unpack all returned values
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}, T-Stat = {:.2f}, p-val = {:.2f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(63, 75 ))

plt.title('All Stations Daily Average Minimum Temperature Comparison for Each Summer Season')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.05, Standard Error = 0.02, T-Stat = 2.32, p-value = 0.0270
# Daniel Field: Slope = 0.09, Standard Error = 0.03, T-Stat = 3.56, p-value = 0.0016
# Appling Station: Slope = 0.03, Standard Error = 0.03, T-Stat = 1.10, p-val = 0.28
# Johnston Station: Slope = 0.11, Standard Error = 0.03, T-Stat = 3.28, p-val = 0.00
# Louisville Station: Slope = -0.01, Standard Error = 0.02, T-Stat = -0.56, p-val = 0.58
# Waynesboro Station: Slope = 0.09, Standard Error = 0.03, T-Stat = 3.70, p-val = 0.00

# %%
seasonal_avg_tempB = fall_Bdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempD = fall_Ddata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempA = fall_Adata.groupby('seasonal_year')['TMIN'].mean()
#seasonal_avg_tempC = fall_Cdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempJ = fall_Jdata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempL = fall_Ldata.groupby('seasonal_year')['TMIN'].mean()
seasonal_avg_tempW = fall_Wdata.groupby('seasonal_year')['TMIN'].mean()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Calculate overall mean
#overall_meanB = seasonal_avg_tempB.mean()
#overall_meanD = seasonal_avg_tempD.mean()

# Plotting
plt.figure(figsize=(16, 7))
#plt.plot(yearsB, temp_valuesB,'o', color='orange', label='Bush Winter Tmax')
#plt.plot(yearsD, temp_valuesD,'o', color='red', label='Daniel Winter Tmax')

# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='orange',linewidth=2, label='Bush Field Trend Line')
#plt.axhline(y=overall_meanB, color='blue', linestyle='--', linewidth=1.5, label='Overall Bush Field Mean')

plt.plot(yearsD, trend_lineD, 'r-',linewidth=2, label='Daniel Field Trend Line')
#plt.axhline(y=overall_meanD, color='Green', linestyle='--', linewidth=1.5, label='Overall Daniel Field Mean')

plt.plot(yearsA, trend_lineA, 'b-',linewidth=2, label='Appling station Trend Line')

#plt.plot(yearsC, trend_lineC, 'g-',linewidth=2, label='Clarks hill station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g-',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y-',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    return slope, SE

# Example calculation for each dataset
slopeB, SEB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeB, SEB))

slopeD, SED = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeD, SED))

slopeA, SEA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeA, SEA))

slopeJ, SEJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeJ, SEJ))

slopeL, SEL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeL, SEL))

slopeW, SEW = calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f}".format(slopeW, SEW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(46, 62 ))

plt.title('All Stations Daily Average Minimum Temperature Comparison for Each Fall Season')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.06, Standard Error = 0.04
# Daniel Field: Slope = 0.09, Standard Error = 0.04
# Appling Station: Slope = 0.05, Standard Error = 0.04
# Johnston Station: Slope = 0.16, Standard Error = 0.06
# Louisville Station: Slope = -0.06, Standard Error = 0.05
# Waynesboro Station: Slope = 0.06, Standard Error = 0.05

# %%
seasonal_avg_tempB = Winter_Bdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempD = Winter_Ddata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempA = Winter_Adata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempJ = Winter_Jdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempL = Winter_Ldata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempW = Winter_Wdata.groupby('seasonal_year')['PRCP'].sum()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Calculate overall mean
#overall_meanB = seasonal_avg_tempB.mean()
#overall_meanD = seasonal_avg_tempD.mean()

# Plotting
plt.figure(figsize=(16, 7))
plt.bar(yearsA, temp_valuesA, color='skyblue', label='Appling Station Total Winter Prcp')
# Plotting trend line and overall mean
plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--',linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(0, 22,2))

plt.title('All Stations Total Precipitation Comparison for Each Winter Season')
plt.xlabel('Winter Season (Year Ending)')
plt.ylabel('Total Precipitation in inches')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.11, Standard Error = 0.06,T-Stat = 1.87, p-value = 0.0708
# Daniel Field: Slope = 0.30, Standard Error = 0.08,T-Stat = 3.81, p-value = 0.0008
# Appling Station: Slope = 0.06, Standard Error = 0.06,T-Stat = 1.01, p-value = 0.3189
# Johnston Station: Slope = 0.02, Standard Error = 0.06,T-Stat = 0.29, p-value = 0.7724
# Louisville Station: Slope = 0.05, Standard Error = 0.07,T-Stat = 0.75, p-value = 0.4581
# Waynesboro Station: Slope = 0.09, Standard Error = 0.07,T-Stat = 1.35, p-value = 0.1875

# %%
seasonal_avg_tempB = spring_Bdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempD = spring_Ddata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempA = spring_Adata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempJ = spring_Jdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempL = spring_Ldata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempW = spring_Wdata.groupby('seasonal_year')['PRCP'].sum()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))

# Plotting trend line and overall mean
plt.bar(yearsW, temp_valuesW, color='#CBC3E3', label='Waynesboro Station Total Winter Prcp')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(0, 20))

plt.title('All Stations Total Precipitation Comparison for Each Spring Season')
plt.xlabel('YEAR')
plt.ylabel('Total Precipitation in inches')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.08, Standard Error = 0.07,T-Stat = 1.13, p-value = 0.2670
# Daniel Field: Slope = 0.07, Standard Error = 0.09,T-Stat = 0.82, p-value = 0.4213
# Appling Station: Slope = -0.02, Standard Error = 0.08,T-Stat = -0.23, p-value = 0.8184
# Johnston Station: Slope = -0.04, Standard Error = 0.08,T-Stat = -0.53, p-value = 0.6012
# Louisville Station: Slope = -0.02, Standard Error = 0.09,T-Stat = -0.27, p-value = 0.7904
# Waynesboro Station: Slope = 0.05, Standard Error = 0.08,T-Stat = 0.56, p-value = 0.5817

# %%
seasonal_avg_tempB = summer_Bdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempD = summer_Ddata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempA = summer_Adata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempJ = summer_Jdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempL = summer_Ldata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempW = summer_Wdata.groupby('seasonal_year')['PRCP'].sum()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
# Plotting trend line and overall mean
plt.bar(yearsW, temp_valuesW, color='#CBC3E3', label='Waynesboro Station Total Summer Prcp')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(0, 31,2))

plt.title('All Stations Total Precipitation Comparison for Each Summer Season')
plt.xlabel('YEAR')
plt.ylabel('Total Precipitation in inches')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.0828, Standard Error = 0.09,T-Stat = 0.97, p-value = 0.3402
# Daniel Field: Slope = 0.0501, Standard Error = 0.15,T-Stat = 0.33, p-value = 0.7467
# Appling Station: Slope = 0.0247, Standard Error = 0.08,T-Stat = 0.31, p-value = 0.7606
# Johnston Station: Slope = -0.0024, Standard Error = 0.09,T-Stat = -0.03, p-value = 0.9792
# Louisville Station: Slope = -0.0007, Standard Error = 0.09,T-Stat = -0.01, p-value = 0.9940
# Waynesboro Station: Slope = -0.0487, Standard Error = 0.08,T-Stat = -0.60, p-value = 0.5505

# %%
seasonal_avg_tempB = fall_Bdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempD = fall_Ddata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempA = fall_Adata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempJ = fall_Jdata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempL = fall_Ldata.groupby('seasonal_year')['PRCP'].sum()
seasonal_avg_tempW = fall_Wdata.groupby('seasonal_year')['PRCP'].sum()

# Setup for plotting
yearsB = seasonal_avg_tempB.index
temp_valuesB = seasonal_avg_tempB.values

yearsD = seasonal_avg_tempD.index
temp_valuesD = seasonal_avg_tempD.values

yearsA = seasonal_avg_tempA.index
temp_valuesA = seasonal_avg_tempA.values

#yearsC = seasonal_avg_tempC.index
#temp_valuesC = seasonal_avg_tempC.values

yearsJ = seasonal_avg_tempJ.index
temp_valuesJ = seasonal_avg_tempJ.values

yearsL = seasonal_avg_tempL.index
temp_valuesL = seasonal_avg_tempL.values

yearsW = seasonal_avg_tempW.index
temp_valuesW = seasonal_avg_tempW.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, temp_valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, temp_valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, temp_valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

#slopeC, interceptC = np.polyfit(yearsC, temp_valuesC, 1)
#trend_lineC = slopeC * yearsC + interceptC

slopeJ, interceptJ = np.polyfit(yearsJ, temp_valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, temp_valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, temp_valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
# Plotting trend line and overall mean
plt.bar(yearsW, temp_valuesW, color='#CBC3E3', label='Waynesboro Station Total Fall Prcp')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y, 1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, temp_valuesB)
print("Bush Field: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, temp_valuesD)
print("Daniel Field: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, temp_valuesA)
print("Appling Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, temp_valuesJ)
print("Johnston Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, temp_valuesL)
print("Louisville Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, temp_valuesW)
print("Waynesboro Station: Slope = {:.4f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(0, 28,2))

plt.title('All Stations Total Precipitation Comparison for Each Fall Season')
plt.xlabel('YEAR')
plt.ylabel('Total Precipitation in inches')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = -0.0458, Standard Error = 0.08,T-Stat = -0.61, p-value = 0.5469
# Daniel Field: Slope = -0.0163, Standard Error = 0.10,T-Stat = -0.16, p-value = 0.8716
# Appling Station: Slope = -0.0384, Standard Error = 0.08,T-Stat = -0.49, p-value = 0.6262
# Johnston Station: Slope = -0.0518, Standard Error = 0.08,T-Stat = -0.63, p-value = 0.5338
# Louisville Station: Slope = -0.0684, Standard Error = 0.08,T-Stat = -0.87, p-value = 0.3888
# Waynesboro Station: Slope = -0.1655, Standard Error = 0.10,T-Stat = -1.69, p-value = 0.1005

# %%
allyear_Bdata = weather_B[(weather_B.index.month >= 1)&(weather_B.index.month <=12)& (weather_B.index.year >=1991)& (weather_B.index.year<=2023)]
allyear_Ddata = weather_D[(weather_D.index.month >=1) &(weather_D.index.month <=12)& (weather_D.index.year >=1998)& (weather_D.index.year<=2023)]
allyear_Adata = weather_A[(weather_A.index.month >=1) &(weather_A.index.month <=12)& (weather_A.index.year >=1991)& (weather_A.index.year<=2023)]
allyear_Jdata = weather_J[(weather_J.index.month >=1) &(weather_J.index.month <=12)& (weather_J.index.year >=1991)& (weather_J.index.year<=2023)]
allyear_Ldata = weather_L[(weather_L.index.month >=1) &(weather_L.index.month <=12)& (weather_L.index.year >=1991)& (weather_L.index.year<=2023)]
allyear_Wdata = weather_W[(weather_W.index.month >=1) &(weather_W.index.month <=12)& (weather_W.index.year >=1991)& (weather_W.index.year<=2023)]

# %%
days_over_95_B = allyear_Bdata[allyear_Bdata['TMAX'] >= 95.0].groupby('seasonal_year').size()
days_over_95_D = allyear_Ddata[allyear_Ddata['TMAX'] >= 95.0].groupby('seasonal_year').size()
days_over_95_A = allyear_Adata[allyear_Adata['TMAX'] >= 95.0].groupby('seasonal_year').size()
days_over_95_J = allyear_Jdata[allyear_Jdata['TMAX'] >= 95.0].groupby('seasonal_year').size()
days_over_95_L = allyear_Ldata[allyear_Ldata['TMAX'] >= 95.0].groupby('seasonal_year').size()
days_over_95_W = allyear_Wdata[allyear_Wdata['TMAX'] >= 95.0].groupby('seasonal_year').size()

# Setup for plotting
yearsB = days_over_95_B.index
valuesB = days_over_95_B.values

yearsD = days_over_95_D.index
valuesD = days_over_95_D.values

yearsA = days_over_95_A.index
valuesA = days_over_95_A.values

yearsJ = days_over_95_J.index
valuesJ = days_over_95_J.values

yearsL = days_over_95_L.index
valuesL = days_over_95_L.values

yearsW = days_over_95_W.index
valuesW = days_over_95_W.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

slopeJ, interceptJ = np.polyfit(yearsJ, valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
plt.bar(yearsW, valuesW, color='#CBC3E3', label='Waynesboro Station days>=95')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y,1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
plt.yticks(np.arange(0, 91, 5))

plt.title('Comparison of all Stations for Number of Days 95F and more for each Year(1991-2023)')
plt.xlabel('YEAR')
plt.ylabel('Number of day over 95 F')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.42, Standard Error = 0.38,T-Stat = 1.13, p-value = 0.2690
# Daniel Field: Slope = 0.61, Standard Error = 0.38,T-Stat = 1.61, p-value = 0.1207
# Appling Station: Slope = -0.06, Standard Error = 0.27,T-Stat = -0.24, p-value = 0.8154
# Johnston Station: Slope = -0.58, Standard Error = 0.31,T-Stat = -1.84, p-value = 0.0748
# Louisville Station: Slope = -0.31, Standard Error = 0.34,T-Stat = -0.92, p-value = 0.3653
# Waynesboro Station: Slope = -0.15, Standard Error = 0.30,T-Stat = -0.50, p-value = 0.6184

# %%
days_over_100_B = allyear_Bdata[allyear_Bdata['TMAX'] >= 100.0].groupby('seasonal_year').size()
days_over_100_D = allyear_Ddata[allyear_Ddata['TMAX'] >= 100.0].groupby('seasonal_year').size()
days_over_100_A = allyear_Adata[allyear_Adata['TMAX'] >= 100.0].groupby('seasonal_year').size()
days_over_100_J = allyear_Jdata[allyear_Jdata['TMAX'] >= 100.0].groupby('seasonal_year').size()
days_over_100_L = allyear_Ldata[allyear_Ldata['TMAX'] >= 100.0].groupby('seasonal_year').size()
days_over_100_W = allyear_Wdata[allyear_Wdata['TMAX'] >= 100.0].groupby('seasonal_year').size()

# Setup for plotting
yearsB = days_over_100_B.index
valuesB = days_over_100_B.values

yearsD = days_over_100_D.index
valuesD = days_over_100_D.values

yearsA = days_over_100_A.index
valuesA = days_over_100_A.values

yearsJ = days_over_100_J.index
valuesJ = days_over_100_J.values

yearsL = days_over_100_L.index
valuesL = days_over_100_L.values

yearsW = days_over_100_W.index
valuesW = days_over_100_W.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

slopeJ, interceptJ = np.polyfit(yearsJ, valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
plt.bar(yearsD, valuesD, color='#FFDBBB', label='Daniel Field days>=100')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y,1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
#plt.yticks(np.arange(0, 91, 5))

plt.title('Comparison of all Stations for Number of Days 100F and more for each Year(1991-2023)')
plt.xlabel('YEAR')
plt.ylabel('Number of day over 100 F')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = -0.05, Standard Error = 0.19,T-Stat = -0.25, p-value = 0.8019
# Daniel Field: Slope = 0.03, Standard Error = 0.13,T-Stat = 0.24, p-value = 0.8145
# Appling Station: Slope = -0.10, Standard Error = 0.09,T-Stat = -1.15, p-value = 0.2706
# Johnston Station: Slope = -0.10, Standard Error = 0.18,T-Stat = -0.59, p-value = 0.5635
# Louisville Station: Slope = -0.15, Standard Error = 0.14,T-Stat = -1.09, p-value = 0.2917
# Waynesboro Station: Slope = -0.02, Standard Error = 0.12,T-Stat = -0.19, p-value = 0.8533

# %%
days_over_3_B = allyear_Bdata[allyear_Bdata['PRCP'] >= 3.0].groupby('seasonal_year').size()
days_over_3_D = allyear_Ddata[allyear_Ddata['PRCP'] >= 3.0].groupby('seasonal_year').size()
days_over_3_A = allyear_Adata[allyear_Adata['PRCP'] >= 3.0].groupby('seasonal_year').size()
days_over_3_J = allyear_Jdata[allyear_Jdata['PRCP'] >= 3.0].groupby('seasonal_year').size()
days_over_3_L = allyear_Ldata[allyear_Ldata['PRCP'] >= 3.0].groupby('seasonal_year').size()
days_over_3_W = allyear_Wdata[allyear_Wdata['PRCP'] >= 3.0].groupby('seasonal_year').size()

# Setup for plotting
yearsB = days_over_3_B.index
valuesB = days_over_3_B.values

yearsD = days_over_3_D.index
valuesD = days_over_3_D.values

yearsA = days_over_3_A.index
valuesA = days_over_3_A.values

yearsJ = days_over_3_J.index
valuesJ = days_over_3_J.values

yearsL = days_over_3_L.index
valuesL = days_over_3_L.values

yearsW = days_over_3_W.index
valuesW = days_over_3_W.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

slopeJ, interceptJ = np.polyfit(yearsJ, valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
plt.bar(yearsD, valuesD, color='#FFCCCB', label='Daniel Field Prcp>3 inches')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y,1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
#plt.yticks(np.arange(0, 4, 1))

plt.title('Comparison of Annual Days with Precipitation Exceeding 3 Inches at All Stations (1991-2024)')
plt.xlabel('YEAR')
plt.ylabel('Number of Days with Precipitation Above 3 Inches')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = 0.02, Standard Error = 0.01,T-Stat = 1.53, p-value = 0.1417
# Daniel Field: Slope = 0.03, Standard Error = 0.02,T-Stat = 1.50, p-value = 0.1591
# Appling Station: Slope = -0.01, Standard Error = 0.01,T-Stat = -0.54, p-value = 0.5978
# Johnston Station: Slope = 0.02, Standard Error = 0.02,T-Stat = 1.41, p-value = 0.1792
# Louisville Station: Slope = 0.01, Standard Error = 0.02,T-Stat = 0.71, p-value = 0.4849
# Waynesboro Station: Slope = -0.01, Standard Error = 0.03,T-Stat = -0.20, p-value = 0.8447

# %%
days_over_0_B = allyear_Bdata[allyear_Bdata['PRCP'] == 0.0].groupby('seasonal_year').size()
days_over_0_D = allyear_Ddata[allyear_Ddata['PRCP'] == 0.0].groupby('seasonal_year').size()
days_over_0_A = allyear_Adata[allyear_Adata['PRCP'] == 0.0].groupby('seasonal_year').size()
days_over_0_J = allyear_Jdata[allyear_Jdata['PRCP'] == 0.0].groupby('seasonal_year').size()
days_over_0_L = allyear_Ldata[allyear_Ldata['PRCP'] == 0.0].groupby('seasonal_year').size()
days_over_0_W = allyear_Wdata[allyear_Wdata['PRCP'] == 0.0].groupby('seasonal_year').size()

# Setup for plotting
yearsB = days_over_0_B.index
valuesB = days_over_0_B.values

yearsD = days_over_0_D.index
valuesD = days_over_0_D.values

yearsA = days_over_0_A.index
valuesA = days_over_0_A.values

yearsJ = days_over_0_J.index
valuesJ = days_over_0_J.values

yearsL = days_over_0_L.index
valuesL = days_over_0_L.values

yearsW = days_over_0_W.index
valuesW = days_over_0_W.values

# Calculate the linear trend line
slopeB, interceptB = np.polyfit(yearsB, valuesB, 1)
trend_lineB = slopeB * yearsB + interceptB

slopeD, interceptD = np.polyfit(yearsD, valuesD, 1)
trend_lineD = slopeD * yearsD + interceptD

slopeA, interceptA = np.polyfit(yearsA, valuesA, 1)
trend_lineA = slopeA * yearsA + interceptA

slopeJ, interceptJ = np.polyfit(yearsJ, valuesJ, 1)
trend_lineJ = slopeJ * yearsJ + interceptJ

slopeL, interceptL = np.polyfit(yearsL, valuesL, 1)
trend_lineL = slopeL * yearsL + interceptL

slopeW, interceptW = np.polyfit(yearsW, valuesW, 1)
trend_lineW = slopeW * yearsW + interceptW

# Plotting
plt.figure(figsize=(16, 7))
plt.bar(yearsD, valuesD, color='#FFCCCB', label='Daniel Field Prcp>0 inches')

plt.plot(yearsB, trend_lineB, color='#DC4D01',linestyle='--',linewidth=2, label='Bush Field Trend Line')

plt.plot(yearsD, trend_lineD, 'r--',linewidth=2, label='Daniel Field Trend Line')

plt.plot(yearsA, trend_lineA, 'b--',linewidth=2, label='Appling station Trend Line')

plt.plot(yearsJ, trend_lineJ, 'g--',linewidth=2, label='Johnston station Trend Line')

plt.plot(yearsL, trend_lineL, 'y--',linewidth=2, label='Louisville station Trend Line')

plt.plot(yearsW, trend_lineW, color='purple',linestyle='--', linewidth=2, label='Waynesboro station Trend Line')

import scipy.stats as stats

from scipy.stats import t
def calculate_slope_and_error(x, y):
    # Perform linear regression
    slope, intercept = np.polyfit(x, y,1)
    # Predict the values
    pred = np.polyval([slope, intercept], x)
    # Calculate the residuals
    residuals = y - pred
    # Standard error of the slope estimate
    N = len(x)
    SE = np.sqrt(np.sum(residuals**2) / (N - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))
    # Calculate the t-statistic for the slope
    t_statistic = slope / SE
    # Calculate the p-value assuming a two-tailed test
    df = N - 2  # degrees of freedom
    p_value = t.sf(np.abs(t_statistic), df) * 2
    return slope, SE, t_statistic, p_value

# Example calculation for each dataset
slopeB, SEB, t_statB, p_valueB = calculate_slope_and_error(yearsB, valuesB)
print("Bush Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeB, SEB, t_statB, p_valueB))

slopeD, SED, t_statD, p_valueD = calculate_slope_and_error(yearsD, valuesD)
print("Daniel Field: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeD, SED, t_statD, p_valueD))

slopeA, SEA, t_statA, p_valueA = calculate_slope_and_error(yearsA, valuesA)
print("Appling Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeA, SEA, t_statA, p_valueA))

slopeJ, SEJ, t_statJ, p_valueJ = calculate_slope_and_error(yearsJ, valuesJ)
print("Johnston Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeJ, SEJ, t_statJ, p_valueJ))

slopeL, SEL, t_statL, p_valueL = calculate_slope_and_error(yearsL, valuesL)
print("Louisville Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeL, SEL, t_statL, p_valueL))

slopeW, SEW , t_statW, p_valueW= calculate_slope_and_error(yearsW, valuesW)
print("Waynesboro Station: Slope = {:.2f}, Standard Error = {:.2f},T-Stat = {:.2f}, p-value = {:.4f}".format(slopeW, SEW,  t_statW, p_valueW))

tick_interval = 2  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in yearsB if year % tick_interval == 0])
#plt.yticks(np.arange(0, 95, 4))

plt.title('Comparison of Annual Days with Precipitation Exceeding 0 Inches at All Stations (1991-2024)')
plt.xlabel('YEAR')
plt.ylabel('Number of Days with Precipitation Above 0 Inches')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bush Field: Slope = -0.21, Standard Error = 0.28,T-Stat = -0.76, p-value = 0.4522
# Daniel Field: Slope = 0.53, Standard Error = 0.47,T-Stat = 1.13, p-value = 0.2688
# Appling Station: Slope = -0.45, Standard Error = 0.29,T-Stat = -1.51, p-value = 0.1401
# Johnston Station: Slope = -0.49, Standard Error = 0.30,T-Stat = -1.62, p-value = 0.1146
# Louisville Station: Slope = -0.63, Standard Error = 0.80,T-Stat = -0.78, p-value = 0.4390
# Waynesboro Station: Slope = 0.59, Standard Error = 0.72,T-Stat = 0.81, p-value = 0.4229
