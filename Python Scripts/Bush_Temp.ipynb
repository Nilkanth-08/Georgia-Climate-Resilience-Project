# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# Load your data
weather = pd.read_csv("Bush field data.csv", parse_dates=['DATE'], index_col='DATE')

# %%
weather
# Out:
#                 STATION                               NAME  LATITUDE  \
# DATE
# 01-01-1945  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 02-01-1945  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 03-01-1945  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 04-01-1945  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 05-01-1945  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 14-06-2024  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 15-06-2024  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 16-06-2024  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 17-06-2024  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 18-06-2024  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             LONGITUDE  ELEVATION  PRCP  TAVG  TMAX  TMIN
# DATE
# 01-01-1945  -81.96353       40.9  0.31   NaN  63.0  30.0
# 02-01-1945  -81.96353       40.9  0.00   NaN  46.0  24.0
# 03-01-1945  -81.96353       40.9  0.00   NaN  52.0  31.0
# 04-01-1945  -81.96353       40.9  0.00   NaN  58.0  37.0
# 05-01-1945  -81.96353       40.9  0.00   NaN  58.0  33.0
# ...               ...        ...   ...   ...   ...   ...
# 14-06-2024  -81.96353       40.9  0.00  78.0  94.0  61.0
# 15-06-2024  -81.96353       40.9  0.30  81.0  97.0  67.0
# 16-06-2024  -81.96353       40.9  0.55  79.0  93.0  69.0
# 17-06-2024  -81.96353       40.9  0.46  78.0  89.0  70.0
# 18-06-2024  -81.96353       40.9   NaN  75.0   NaN   NaN
#
# [29024 rows x 9 columns]

# %%
weather.index = pd.to_datetime(weather.index, format='%d-%m-%Y')

# %%
weather.index
# Out:
# DatetimeIndex(['1945-01-01', '1945-01-02', '1945-01-03', '1945-01-04',
#                '1945-01-05', '1945-01-06', '1945-01-07', '1945-01-08',
#                '1945-01-09', '1945-01-10',
#                ...
#                '2024-06-09', '2024-06-10', '2024-06-11', '2024-06-12',
#                '2024-06-13', '2024-06-14', '2024-06-15', '2024-06-16',
#                '2024-06-17', '2024-06-18'],
#               dtype='datetime64[ns]', name='DATE', length=29024, freq=None)

# %%
weather['seasonal_year'] = weather.index.year + (weather.index.month == 12)

# %%
weather['seasonal_year']
# Out:
# DATE
# 1945-01-01    1945
# 1945-01-02    1945
# 1945-01-03    1945
# 1945-01-04    1945
# 1945-01-05    1945
#               ...
# 2024-06-14    2024
# 2024-06-15    2024
# 2024-06-16    2024
# 2024-06-17    2024
# 2024-06-18    2024
# Name: seasonal_year, Length: 29024, dtype: int32

# %%
# Filter for winter months: December, January, and February
winter_data = weather[(weather.index.month == 12) &(weather.index.year>=1945) | (weather.index.month <= 2) & (weather.index.year>1945)]

# %%
winter_data
# Out:
#                 station                               name  latitude  \
# DATE
# 1945-12-01  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-02  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-03  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-04  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-05  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 2024-02-25  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-26  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-27  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-28  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-29  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             longitude  elevation  prcp  tavg  tmax  tmin  seasonal_year
# DATE
# 1945-12-01  -81.96353       40.9  0.00   NaN  58.0  32.0           1946
# 1945-12-02  -81.96353       40.9  0.00   NaN  60.0  34.0           1946
# 1945-12-03  -81.96353       40.9  0.00   NaN  61.0  39.0           1946
# 1945-12-04  -81.96353       40.9  2.27   NaN  58.0  43.0           1946
# 1945-12-05  -81.96353       40.9  0.31   NaN  46.0  36.0           1946
# ...               ...        ...   ...   ...   ...   ...            ...
# 2024-02-25  -81.96353       40.9  0.00  48.0  61.0  30.0           2024
# 2024-02-26  -81.96353       40.9  0.00  51.0  74.0  29.0           2024
# 2024-02-27  -81.96353       40.9  0.00  58.0  72.0  42.0           2024
# 2024-02-28  -81.96353       40.9  0.12  67.0  77.0  48.0           2024
# 2024-02-29  -81.96353       40.9  0.00  52.0  57.0  41.0           2024
#
# [7130 rows x 10 columns]

# %%
winter_data
# Out:
#                 station                               name  latitude  \
# DATE
# 1945-12-01  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-02  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-03  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-04  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-05  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 2024-02-25  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-26  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-27  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-28  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-29  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             longitude  elevation  prcp  tavg  tmax  tmin  seasonal_year
# DATE
# 1945-12-01  -81.96353       40.9  0.00   NaN  58.0  32.0           1946
# 1945-12-02  -81.96353       40.9  0.00   NaN  60.0  34.0           1946
# 1945-12-03  -81.96353       40.9  0.00   NaN  61.0  39.0           1946
# 1945-12-04  -81.96353       40.9  2.27   NaN  58.0  43.0           1946
# 1945-12-05  -81.96353       40.9  0.31   NaN  46.0  36.0           1946
# ...               ...        ...   ...   ...   ...   ...            ...
# 2024-02-25  -81.96353       40.9  0.00  48.0  61.0  30.0           2024
# 2024-02-26  -81.96353       40.9  0.00  51.0  74.0  29.0           2024
# 2024-02-27  -81.96353       40.9  0.00  58.0  72.0  42.0           2024
# 2024-02-28  -81.96353       40.9  0.12  67.0  77.0  48.0           2024
# 2024-02-29  -81.96353       40.9  0.00  52.0  57.0  41.0           2024
#
# [7130 rows x 10 columns]

# %%
winter_data.columns = winter_data.columns.str.lower()

# %%
winter_data
# Out:
#                 station                               name  latitude  \
# DATE
# 1945-12-01  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-02  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-03  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-04  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-05  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 2024-02-25  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-26  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-27  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-28  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-29  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             longitude  elevation  prcp  tavg  tmax  tmin  seasonal_year
# DATE
# 1945-12-01  -81.96353       40.9  0.00   NaN  58.0  32.0           1946
# 1945-12-02  -81.96353       40.9  0.00   NaN  60.0  34.0           1946
# 1945-12-03  -81.96353       40.9  0.00   NaN  61.0  39.0           1946
# 1945-12-04  -81.96353       40.9  2.27   NaN  58.0  43.0           1946
# 1945-12-05  -81.96353       40.9  0.31   NaN  46.0  36.0           1946
# ...               ...        ...   ...   ...   ...   ...            ...
# 2024-02-25  -81.96353       40.9  0.00  48.0  61.0  30.0           2024
# 2024-02-26  -81.96353       40.9  0.00  51.0  74.0  29.0           2024
# 2024-02-27  -81.96353       40.9  0.00  58.0  72.0  42.0           2024
# 2024-02-28  -81.96353       40.9  0.12  67.0  77.0  48.0           2024
# 2024-02-29  -81.96353       40.9  0.00  52.0  57.0  41.0           2024
#
# [7130 rows x 10 columns]

# %%
winter_data['day_of_season'] = winter_data.index.dayofyear - 334  # Adjust day of year to start from Dec 1
winter_data.loc[winter_data['day_of_season'] < 1, 'day_of_season'] += 365  # Adjust for December days

# %%
winter_data
# Out:
#                 station                               name  latitude  \
# DATE
# 1945-12-01  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-02  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-03  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-04  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-12-05  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 2024-02-25  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-26  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-27  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-28  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-02-29  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             longitude  elevation  prcp  tavg  tmax  tmin  seasonal_year  \
# DATE
# 1945-12-01  -81.96353       40.9  0.00   NaN  58.0  32.0           1946
# 1945-12-02  -81.96353       40.9  0.00   NaN  60.0  34.0           1946
# 1945-12-03  -81.96353       40.9  0.00   NaN  61.0  39.0           1946
# 1945-12-04  -81.96353       40.9  2.27   NaN  58.0  43.0           1946
# 1945-12-05  -81.96353       40.9  0.31   NaN  46.0  36.0           1946
# ...               ...        ...   ...   ...   ...   ...            ...
# 2024-02-25  -81.96353       40.9  0.00  48.0  61.0  30.0           2024
# 2024-02-26  -81.96353       40.9  0.00  51.0  74.0  29.0           2024
# 2024-02-27  -81.96353       40.9  0.00  58.0  72.0  42.0           2024
# 2024-02-28  -81.96353       40.9  0.12  67.0  77.0  48.0           2024
# 2024-02-29  -81.96353       40.9  0.00  52.0  57.0  41.0           2024
#
#             day_of_season
# DATE
# 1945-12-01              1
# 1945-12-02              2
# 1945-12-03              3
# 1945-12-04              4
# 1945-12-05              5
# ...                   ...
# 2024-02-25             87
# 2024-02-26             88
# 2024-02-27             89
# 2024-02-28             90
# 2024-02-29             91
#
# [7130 rows x 11 columns]

# %%
seasonal_avg_temp = winter_data.groupby('seasonal_year')['tmax'].mean()

# %%
seasonal_avg_temp
# Out:
# seasonal_year
# 1946    57.588889
# 1947    60.000000
# 1948    55.934066
# 1949    64.422222
# 1950    64.422222
#           ...
# 2020    63.857143
# 2021    60.833333
# 2022    65.466667
# 2023    63.233333
# 2024    61.494505
# Name: tmax, Length: 79, dtype: float64

# %%
seasonal_avg_temp = winter_data.groupby('seasonal_year')['tmax'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='orange', label='Average Winter Tmax')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(52, 70))

plt.title('Bush Field Daily Average Maximum Temperature for Each Winter Season (1945-2024)')
plt.xlabel('Winter Season (Year Ending)')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
Spring_data = weather[(weather.index.month == 3) | (weather.index.month == 4)| (weather.index.month == 5)].copy()

# %%
Spring_data
# Out:
#                 station                               name  latitude  \
# DATE
# 1945-03-01  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-03-02  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-03-03  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-03-04  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 1945-03-05  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# ...                 ...                                ...       ...
# 2024-05-27  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-05-28  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-05-29  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-05-30  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
# 2024-05-31  USW00003820  AUGUSTA BUSH FIELD AIRPORT, GA US  33.36517
#
#             longitude  elevation  prcp  tavg  tmax  tmin  seasonal_year
# DATE
# 1945-03-01  -81.96353       40.9   0.0   NaN  66.0  38.0           1945
# 1945-03-02  -81.96353       40.9   0.0   NaN  77.0  44.0           1945
# 1945-03-03  -81.96353       40.9   0.0   NaN  79.0  55.0           1945
# 1945-03-04  -81.96353       40.9   0.0   NaN  79.0  56.0           1945
# 1945-03-05  -81.96353       40.9   0.0   NaN  67.0  58.0           1945
# ...               ...        ...   ...   ...   ...   ...            ...
# 2024-05-27  -81.96353       40.9   0.0  80.0  88.0  71.0           2024
# 2024-05-28  -81.96353       40.9   0.0  80.0  91.0  64.0           2024
# 2024-05-29  -81.96353       40.9   0.0  76.0  89.0  57.0           2024
# 2024-05-30  -81.96353       40.9   0.0  72.0  85.0  56.0           2024
# 2024-05-31  -81.96353       40.9   0.0  69.0  86.0  53.0           2024
#
# [7360 rows x 10 columns]

# %%
seasonal_avg_temp = Spring_data.groupby('seasonal_year')['tmax'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='orange', label='Average Spring Tmax')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(70, 85))

plt.title('Bush Field Daily Average Maximum Temperature for Each Spring Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
Summer_data = weather[(weather.index.month == 6) | (weather.index.month == 7)| (weather.index.month == 8)].copy()

# %%
seasonal_avg_temp = Summer_data.groupby('seasonal_year')['tmax'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='orange', label='Average Summer Tmax')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(85, 100))

plt.title('Bush Field Daily Average Maximum Temperature for Each Summer Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
Fall_data = weather[(weather.index.month == 9) | (weather.index.month == 10)| (weather.index.month == 11)].copy()

# %%
seasonal_avg_temp = Fall_data.groupby('seasonal_year')['tmax'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='orange', label='Average Fall Tmax')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(71, 85))

plt.title('Bush Field Daily Average Maximum Temperature for Each Fall Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Maximum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
seasonal_avg_temp = winter_data.groupby('seasonal_year')['tmin'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='skyblue', label='Average Winter Tmin')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(27, 46))

plt.title('Bush Field Daily Average Minimum Temperature for Each Winter Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
seasonal_avg_temp = Spring_data.groupby('seasonal_year')['tmin'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='skyblue', label='Average Spring Tmin')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(44,59))

plt.title('Bush Field Daily Average Minimum Temperature for Each Spring Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
seasonal_avg_temp = Summer_data.groupby('seasonal_year')['tmin'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='skyblue', label='Average Summer Tmin')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(63, 75))

plt.title('Bush Field Daily Average Minimum Temperature for Each Summer Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()

# %%
seasonal_avg_temp = Fall_data.groupby('seasonal_year')['tmin'].mean()

# Setup for plotting
years = seasonal_avg_temp.index
temp_values = seasonal_avg_temp.values

# Calculate the linear trend line
slope, intercept = np.polyfit(years, temp_values, 1)
trend_line = slope * years + intercept

# Calculate overall mean
overall_mean = seasonal_avg_temp.mean()

# Plotting
plt.figure(figsize=(16, 5))
plt.plot(years, temp_values,'o', color='skyblue', label='Average Fall Tmin')

# Plotting trend line and overall mean
plt.plot(years, trend_line, 'r-',linewidth=2, label='Trend Line')
plt.axhline(y=overall_mean, color='blue', linestyle='--', linewidth=1, label='Overall Mean')

tick_interval = 3  # Adjust this value as needed for optimal spacing
plt.xticks([year for year in years if year % tick_interval == 0])
plt.yticks(np.arange(45, 62))

plt.title('Bush Field Daily Average Minimum Temperature for Each Fall Season (1945-2024)')
plt.xlabel('YEAR')
plt.ylabel('Average Minimum Temperature (Farenheit)')
plt.legend()
plt.grid(True)
plt.show()
